# %% [markdown]
# # Pt-C Catalyst

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from functions import *

# %%
path = os.path.join("../", "Pt-C Catalyst")

# %% [markdown]
# ## 1- Impedance : Various SBH%

# %%
data = load_data(os.path.join(path, "1.csv"))

# %%
impedance_plot(data, SBH=1)

# %%
impedance_plot(data, SBH=5)

# %%
impedance_plot(data, V=0.5)

# %%
impedance_plot(data, V=0.3)
