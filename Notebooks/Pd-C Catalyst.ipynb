# %% [markdown]
# # Pd-C Catalyst

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from functions import *

# %%
path = os.path.join("../", "Pd-C Catalyst")

# %% [markdown]
# ## 1- Impedance : Various Pd/C Loading and SBH%

# %%
data = load_data(os.path.join(path, "1.csv"))

# %%
impedance_plot(data, CL=4.4, SBH=1)

# %%
impedance_plot(data, CL=8.8, V=0.5)

# %%
impedance_plot(data, V=0.5, SBH=3)

# %% [markdown]
# ## 2- Impedance : Various Pd/C Loading and SBH% with O2

# %%
data = load_data(os.path.join(path, "2.csv"))

# %%
impedance_plot(data, CL=8.8, SBH=5)

# %%
impedance_plot(data, CL=17.7, V=0.5)

# %%
impedance_plot(data, SBH=5, V=0.7)

# %% [markdown]
# ## 3- Polarization : Various Pd/C Loading and SBH%

# %%
data = load_data(os.path.join(path, "3.csv"))

# %%
polarization_plot(data, SBH=1, CL=4.4)

# %%
polarization_plot(data, SBH=5, CL=13.4)

# %% [markdown]
# ## 4- Polarization : Various Pd/C Loading and SBH% with Air

# %%
data = load_data(os.path.join(path, "4.csv"))

# %%
polarization_plot(data, SBH=5, CL=8.8)

# %% [markdown]
# ## 5- Polarization : Various Pd/C Loading and SBH% with O2

# %%
data = load_data(os.path.join(path, "5.csv"))

# %%
polarization_plot(data, SBH=5, CL=8.8)
