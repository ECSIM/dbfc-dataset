# %% [markdown]
# # Acta Catalyst

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from functions import *

# %%
path = os.path.join("../", "Acta Catalyst")

# %% [markdown]
# ## 1- Impedance : Various Acta AnodeTM Loading and SBH%

# %%
data = load_data(os.path.join(path,"1.csv"), is_header=True)

# %%
impedance_plot(data, set_index=1)
