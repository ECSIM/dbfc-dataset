# %% [markdown]
# # Acta Catalyst

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from functions import *

# %%
path = os.path.join("../", "Acta Catalyst")

# %% [markdown]
# ## 1- Impedance : Various Acta AnodeTM Loading and SBH%

# %%
(data, header) = load_data(os.path.join(path,"1.csv"), is_header=True)

# %%
impedance_plot(data, 1, 4.4, header)

# %%
impedance_plot(data, 3, 4.4, header)

# %%
impedance_plot(data, 5, 4.4, header)

# %%
impedance_plot(data, 8, 4.4, header)

# %%
impedance_plot(data, 1, 8.8, header)

# %%
impedance_plot(data, 3, 8.8, header)

# %%
impedance_plot(data, 5, 8.8, header)

# %%
impedance_plot(data, 8, 8.8, header)

# %%
impedance_plot(data, 1, 13.3, header)

# %%
impedance_plot(data, 3, 13.3, header)

# %%
impedance_plot(data, 5, 13.3, header)

# %%
impedance_plot(data, 8, 13.3, header)

# %%
impedance_plot(data, 1, 17.7, header)

# %%
impedance_plot(data, 3, 17.7, header)

# %%
impedance_plot(data, 5, 17.7, header)

# %%
impedance_plot(data, 8, 17.7, header)
