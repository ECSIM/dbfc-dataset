# %% [markdown]
# # Acta Catalyst

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from functions import *

# %%
path = os.path.join("../", "Acta Catalyst")

# %% [markdown]
# ## 1- Impedance : Various Acta AnodeTM Loading and SBH%

# %%
data = load_data(os.path.join(path,"1.csv"))

# %%
impedance_plot(data, SBH=1, CL=4.4)

# %%
impedance_plot(data, SBH=8, V=0.5)

# %%
impedance_plot(data, CL=17.7, V=0.7)
